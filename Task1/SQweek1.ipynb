# %% [markdown]
# Answers for week 1
#
# * Name: Jesse van der Meulen
# * Username: jrhmeulen
# * Student s-number: S6445128
# * Group: AS1

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# $$F=G\frac{m_1m_2}{r^2}$$

# %%
from scipy.constants import G

m_1=7.342e22
m_2=5.9722e24
r=385000600

F=G*(m_1*m_2)/(r**2)

print(F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# Question 1.15:
# 1) The command pwd will give the path of folders needed to get to Downloads. E.g. /Users/users/jrhmeulen/Downloads
#
# 2) For . it will tell you which directory you are currently in, and stay there. The command .. will bring you one directory up, the parent directory, thus for in Downloads for example it will bring me to /Users/users/jrhmeulen.

# %% [markdown]
# Question 1.16:
# 1) cd ~/Desktop

# %% [markdown]
# Question 1.19
# 1) This command will list all documents that before the point have a number in 0-9 in their name, and after the point has either .o or .c
#
# 2) The square brackets indicate the range of numbers for [0-9] and for [co] it means that after the point i has to either have c or an o
#
# 3) The difference is that in this one it only lists files that have the extension .co, not .c or .o but ONLY .co
